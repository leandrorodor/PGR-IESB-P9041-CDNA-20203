# %%
# import necessary packages
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
import seaborn as sns
import gc, os
from datetime import datetime

# %matplotlib inline

# %%
weather2014 = pd.read_csv('/Users/leandrorodordeolrodoriveira/Documents/github/PGR-IESB-P9041-CDNA-20203/montreal/data/weather2014.csv')
weather2015 = pd.read_csv('/Users/leandrorodordeolrodoriveira/Documents/github/PGR-IESB-P9041-CDNA-20203/montreal/data/weather2015.csv')
weather2016 = pd.read_csv('/Users/leandrorodordeolrodoriveira/Documents/github/PGR-IESB-P9041-CDNA-20203/montreal/data/weather2016.csv')
weather2017 = pd.read_csv('/Users/leandrorodordeolrodoriveira/Documents/github/PGR-IESB-P9041-CDNA-20203/montreal/data/weather2017.csv')

# %%
weather2014.tail()
# Out:
#        Longitude (x)  Latitude (y)     Station Name  Climate ID  \
# 13195         -73.74         45.47  MONTREAL INTL A     7025251
# 13196         -73.74         45.47  MONTREAL INTL A     7025251
# 13197         -73.74         45.47  MONTREAL INTL A     7025251
# 13198         -73.74         45.47  MONTREAL INTL A     7025251
# 13199         -73.74         45.47  MONTREAL INTL A     7025251
#
#                  Date/Time  Year  Month  Day  Hour  Temp (°C)  \
# 13195  2014-12-31 21:00:00  2014     12   31    21       -6.4
# 13196  2014-12-31 22:00:00  2014     12   31    22       -6.3
# 13197  2014-12-31 22:00:00  2014     12   31    22       -6.3
# 13198  2014-12-31 23:00:00  2014     12   31    23       -6.8
# 13199  2014-12-31 23:00:00  2014     12   31    23       -6.8
#
#        Dew Point Temp (°C)  Rel Hum (%)  Wind Dir (10s deg)  Wind Spd (km/h)  \
# 13195                -11.4         68.0                21.0             40.0
# ...

# %% [markdown]
# #### Merging the monthly trips into yearly files
# #### The open data available here from Bixi website has a monthly format. Here I'm combining them into years
